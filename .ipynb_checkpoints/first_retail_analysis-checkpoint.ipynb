# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('../turning_patterns_into_profits/Data/Transactions_all_data.csv')

data.head()
# Out:
#    transaction_id  cust_id       DOB Gender  city_code  tran_date prod_subcat  \
# 0     80712190438   270351  09/26/81      M          5  2/28/2014       Women
# 1     29258453508   270384  11/05/73      F          8  2/27/2014   Computers
# 2     51750724947   273420  07/27/92      M          8  2/24/2014         DIY
# 3     93274880719   271509  08/06/81      M          3  2/24/2014    Children
# 4     51750724947   273420  07/27/92      M          8  2/23/2014         DIY
#
#    prod_subcat_code          prod_cat  prod_cat_code  ...  Rate      Tax  \
# 0                 1          Clothing              1  ...  -772  405.300
# 1                 5       Electronics              3  ... -1497  785.925
# 2                 6             Books              5  ...  -791  166.110
# 3                11  Home and kitchen              6  ... -1363  429.345
# 4                 6             Books              5  ...  -791  166.110
#
# ...

# %%
import datetime

month_list=[]
year_list=[]
mo_yr_list=[]

for each_date in data['tran_date']:
    date= datetime.datetime.strptime(str(each_date), "%m/%d/%Y")
    month_list.append(date.month)
    year_list.append(date.year)
    mo_yr_list.append(f"{date.month}/{date.year}")

# %%
# Checking to make sure new lists are same length as dataframe columns

print(f"month: {len(month_list)}")
print(f"year: {len(year_list)}")
print(f"prod_cat: {len(data['prod_cat'])}")
print(mo_yr_list)
# Out:
# month: 23053
# year: 23053
# prod_cat: 23053
# ...

# %%
data["transaction_month"] = month_list
data["transaction_year"] = year_list
data["transaction_MoYr"] = mo_yr_list

data.head()
# Out:
#    transaction_id  cust_id       DOB Gender  city_code  tran_date prod_subcat  \
# 0     80712190438   270351  09/26/81      M          5  2/28/2014       Women
# 1     29258453508   270384  11/05/73      F          8  2/27/2014   Computers
# 2     51750724947   273420  07/27/92      M          8  2/24/2014         DIY
# 3     93274880719   271509  08/06/81      M          3  2/24/2014    Children
# 4     51750724947   273420  07/27/92      M          8  2/23/2014         DIY
#
#    prod_subcat_code          prod_cat  prod_cat_code  ...  Store_type  \
# 0                 1          Clothing              1  ...      e-Shop
# 1                 5       Electronics              3  ...      e-Shop
# 2                 6             Books              5  ...    TeleShop
# 3                11  Home and kitchen              6  ...      e-Shop
# 4                 6             Books              5  ...    TeleShop
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18  Unnamed: 19  \
# ...

# %%
data.drop(["Unnamed: 15", 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'], axis=1)
# Out:
#        transaction_id  cust_id       DOB Gender  city_code  tran_date  \
# 0         80712190438   270351  09/26/81      M          5  2/28/2014
# 1         29258453508   270384  11/05/73      F          8  2/27/2014
# 2         51750724947   273420  07/27/92      M          8  2/24/2014
# 3         93274880719   271509  08/06/81      M          3  2/24/2014
# 4         51750724947   273420  07/27/92      M          8  2/23/2014
# ...               ...      ...       ...    ...        ...        ...
# 23048     94340757522   274550  02/21/72      M          7  1/25/2011
# 23049     89780862956   270022  04/27/84      M          9  1/25/2011
# 23050     85115299378   271020  06/20/76      M          8  1/25/2011
# 23051     72870271171   270911  05/22/70      M          2  1/25/2011
# 23052     77960931771   271961  01/15/82      M          1  1/25/2011
#
#       prod_subcat  prod_subcat_code          prod_cat  prod_cat_code  Qty  \
# ...

# %%
data.head()
# Out:
#    transaction_id  cust_id       DOB Gender  city_code  tran_date prod_subcat  \
# 0     80712190438   270351  09/26/81      M          5  2/28/2014       Women
# 1     29258453508   270384  11/05/73      F          8  2/27/2014   Computers
# 2     51750724947   273420  07/27/92      M          8  2/24/2014         DIY
# 3     93274880719   271509  08/06/81      M          3  2/24/2014    Children
# 4     51750724947   273420  07/27/92      M          8  2/23/2014         DIY
#
#    prod_subcat_code          prod_cat  prod_cat_code  ...  Store_type  \
# 0                 1          Clothing              1  ...      e-Shop
# 1                 5       Electronics              3  ...      e-Shop
# 2                 6             Books              5  ...    TeleShop
# 3                11  Home and kitchen              6  ...      e-Shop
# 4                 6             Books              5  ...    TeleShop
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18  Unnamed: 19  \
# ...

# %%
datag= data.groupby(['transaction_MoYr']).sum()
datag
# Out:
#                   transaction_id    cust_id  city_code  prod_subcat_code  \
# transaction_MoYr
# 1/2011             6955656991362   38207491        826               977
# 1/2012            29004598917948  162677204       3274              3776
# 1/2013            30174687094233  165346418       3411              3583
# 1/2014            33875526310293  184890241       3799              4096
# 10/2011           32354639948867  171853760       3469              3876
# 10/2012           34264966065214  182507587       3756              4006
# 10/2013           33153385342260  181812176       3718              4030
# 11/2011           31640581288651  171904153       3406              3833
# 11/2012           33571984882510  178035927       3548              3966
# 11/2013           28623737735290  160557166       3210              3486
# 12/2011           31339704853387  170655313       3488              3845
# 12/2012           32334208878741  170213833       3350              4029
# ...

# %%
import matplotlib.pyplot as plt

# %%
# testing month of March

X=[[2011], [2012], [2013]]
y=[[376537.175], [1440357.555], [1465626.695]]

plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X,y)
model.score(X,y)
# Out:
# 0.7673919733778626

# %%
predict2014= model.predict([[2014]])

predict2014
# Out:
# array([[2183263.32833338]])
