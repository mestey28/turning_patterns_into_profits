# %% [markdown]
# ##  e-Shop has the highest sales among all store types.
# ##  e-Shop total amount is steadily rising
# ##  e-Shop count of sales declined 2013 but sales amounts still rose
# ##  teleshop and MBR sales are declining
# ##  Flagship sales are leveling off

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data= pd.read_csv("../turning_patterns_into_profits/Data/Transactions_all_data.csv")

data.head()
# Out:
#    transaction_id  cust_id       DOB Gender  city_code  tran_date prod_subcat  \
# 0     80712190438   270351  09/26/81      M          5  2/28/2014       Women
# 1     29258453508   270384  11/05/73      F          8  2/27/2014   Computers
# 2     51750724947   273420  07/27/92      M          8  2/24/2014         DIY
# 3     93274880719   271509  08/06/81      M          3  2/24/2014    Children
# 4     51750724947   273420  07/27/92      M          8  2/23/2014         DIY
#
#    prod_subcat_code          prod_cat  prod_cat_code  ...  Rate      Tax  \
# 0                 1          Clothing              1  ...  -772  405.300
# 1                 5       Electronics              3  ... -1497  785.925
# 2                 6             Books              5  ...  -791  166.110
# 3                11  Home and kitchen              6  ... -1363  429.345
# 4                 6             Books              5  ...  -791  166.110
#
#    total_amt  Store_type Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0  -4265.300      e-Shop         NaN          NaN          NaN          NaN
# 1  -8270.925      e-Shop         NaN          NaN          NaN          NaN
# 2  -1748.110    TeleShop         NaN          NaN          NaN          NaN
# 3  -4518.345      e-Shop         NaN          NaN          NaN          NaN
# 4  -1748.110    TeleShop         NaN          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 21 columns]

# %%
data.drop(["Unnamed: 15", "Unnamed: 16", "Unnamed: 17", "Unnamed: 18", "Unnamed: 19", "Unnamed: 20"], axis=1, inplace=True)

# %%
month_list=[]
year_list=[]
mo_yr_list=[]

for each_date in data['tran_date']:
    date= datetime.datetime.strptime(str(each_date), "%m/%d/%Y")
    month_list.append(date.month)
    year_list.append(date.year)
    mo_yr_list.append(f"{date.month}/{date.year}")

# %%
data["transaction_month"] = month_list
data["transaction_year"] = year_list
data["transaction_MoYr"] = mo_yr_list

data.head()
# Out:
#    transaction_id  cust_id       DOB Gender  city_code  tran_date prod_subcat  \
# 0     80712190438   270351  09/26/81      M          5  2/28/2014       Women
# 1     29258453508   270384  11/05/73      F          8  2/27/2014   Computers
# 2     51750724947   273420  07/27/92      M          8  2/24/2014         DIY
# 3     93274880719   271509  08/06/81      M          3  2/24/2014    Children
# 4     51750724947   273420  07/27/92      M          8  2/23/2014         DIY
#
#    prod_subcat_code          prod_cat  prod_cat_code  Qty  Rate      Tax  \
# 0                 1          Clothing              1   -5  -772  405.300
# 1                 5       Electronics              3   -5 -1497  785.925
# 2                 6             Books              5   -2  -791  166.110
# 3                11  Home and kitchen              6   -3 -1363  429.345
# 4                 6             Books              5   -2  -791  166.110
#
#    total_amt Store_type  transaction_month  transaction_year transaction_MoYr
# 0  -4265.300     e-Shop                  2              2014           2/2014
# 1  -8270.925     e-Shop                  2              2014           2/2014
# 2  -1748.110   TeleShop                  2              2014           2/2014
# 3  -4518.345     e-Shop                  2              2014           2/2014
# 4  -1748.110   TeleShop                  2              2014           2/2014

# %% [markdown]
# ##  E-Shop sales by Category
# ##  all of Category 1 is increasing
# ##  3-4 and 3-5 are declining
# ##  3-9 is steady.  3-10 is increasing
# ##  5-11 is declining

# %%
## create df to analyze category 1

edata1=data.loc[(data['Store_type']=='e-Shop') & (data['prod_cat_code']==1)]
edata1.head()
# Out:
#     transaction_id  cust_id       DOB Gender  city_code  tran_date  \
# 0      80712190438   270351  09/26/81      M          5  2/28/2014
# 26     80712190438   270351  09/26/81      M          5  2/20/2014
# 58     83498320600   273359  05/08/77      M          7  2/18/2014
# 61     78091789730   271030  05/07/79      M          1  2/18/2014
# 87     83108241933   273896  09/24/75      M          6  2/16/2014
#
#    prod_subcat  prod_subcat_code  prod_cat  prod_cat_code  Qty  Rate     Tax  \
# 0        Women                 1  Clothing              1   -5  -772  405.30
# 26       Women                 1  Clothing              1    5   772  405.30
# 58        Mens                 4  Clothing              1    4   861  361.62
# 61        Mens                 4  Clothing              1    1   380   39.90
# 87        Mens                 4  Clothing              1    2   574  120.54
#
#     total_amt Store_type  transaction_month  transaction_year transaction_MoYr
# 0    -4265.30     e-Shop                  2              2014           2/2014
# 26    4265.30     e-Shop                  2              2014           2/2014
# 58    3805.62     e-Shop                  2              2014           2/2014
# 61     419.90     e-Shop                  2              2014           2/2014
# 87    1268.54     e-Shop                  2              2014           2/2014

# %%
edata1_1=edata1.loc[edata1['prod_subcat_code']==1]
edata1_1=edata1_1.groupby('transaction_year').sum()
edata1_1=edata1_1.reset_index()
edata1_1=edata1_1.drop(3)
edata1_1
# Out:
#    transaction_year  transaction_id   cust_id  city_code  prod_subcat_code  \
# 0              2011   5660536941524  30108321        639               111
# 1              2012   6814146921887  34443170        726               127
# 2              2013   6488593313248  36838406        794               136
#
#    prod_cat_code  Qty   Rate        Tax   total_amt  transaction_month
# 0            111  253  61955  31150.245  217447.425                810
# 1            127  280  65351  28792.050  223320.500                819
# 2            136  339  89474  29595.510  280486.570                913

# %%
## Category 1

subcat=[1,3,4]

for each in subcat:
    edata1x=edata1.loc[edata1['prod_subcat_code']==each]
    edata1x=edata1x.groupby('transaction_year').sum()
    edata1x=edata1x.reset_index()
    edata1x=edata1x.drop(3)
    edata1x
    
    X=edata1x["transaction_year"].values.reshape(-1,1)
    y=edata1x["total_amt"].values.reshape(-1,1)
    
    plt.plot(X,y)
    plt.title(f"E-Shop Category 1, Subcategory {each}")
    plt.show()
    
    model=LinearRegression()
    model.fit(X,y)
    Score=model.score(X,y)
    prediction=model.predict([[2014]])
    
    print(f"Model Score: {Score}    2014 Prediction: {prediction}")
# Out:
# Model Score: 0.8192116799649118    2014 Prediction: [[303457.30999999]]
# Model Score: 0.9991646186158388    2014 Prediction: [[318141.65500001]]
# Model Score: 0.9002080056600584    2014 Prediction: [[340106.84500001]]

# %%
## create df to analyze category 3

edata3=data.loc[(data['Store_type']=='e-Shop') & (data['prod_cat_code']==3)]
edata3.head()
# Out:
#     transaction_id  cust_id       DOB Gender  city_code  tran_date  \
# 1      29258453508   270384  11/05/73      F          8  2/27/2014
# 9      50076728598   269014  11/27/79      F          3  2/21/2014
# 10     29258453508   270384  11/05/73      F          8  2/20/2014
# 24     68325723297   268516  09/22/83      F         10  2/20/2014
# 68     43561027610   270244  09/26/88      F          5  2/17/2014
#
#             prod_subcat  prod_subcat_code     prod_cat  prod_cat_code  Qty  \
# 1             Computers                 5  Electronics              3   -5
# 9   Personal Appliances                 8  Electronics              3   -4
# 10            Computers                 5  Electronics              3    5
# 24              Cameras                 9  Electronics              3    1
# 68  Personal Appliances                 8  Electronics              3    1
#
#     Rate      Tax  total_amt Store_type  transaction_month  transaction_year  \
# 1  -1497  785.925  -8270.925     e-Shop                  2              2014
# 9   -581  244.020  -2568.020     e-Shop                  2              2014
# 10  1497  785.925   8270.925     e-Shop                  2              2014
# 24   877   92.085    969.085     e-Shop                  2              2014
# 68   728   76.440    804.440     e-Shop                  2              2014
#
#    transaction_MoYr
# 1            2/2014
# 9            2/2014
# 10           2/2014
# 24           2/2014
# 68           2/2014

# %%
##Category 3

subcat=[4,5,9,10]

for each in subcat:
    edata3x=edata3.loc[edata3['prod_subcat_code']==each]
    edata3x=edata3x.groupby('transaction_year').sum()
    edata3x=edata3x.reset_index()
    edata3x=edata3x.drop(3)
    edata3x
    
    X=edata3x["transaction_year"].values.reshape(-1,1)
    y=edata3x["total_amt"].values.reshape(-1,1)
    
    plt.scatter(X,y)
    plt.ylim(200000,400000)
    plt.title(f"E-Shop Category 3, Subcategory {each}")
    
    
    xx=edata3x["transaction_year"]
    yy= edata3x["total_amt"]
    
    m,b=np.polyfit(xx,yy,1)
    plt.plot(xx, m*xx + b)
    
    plt.show()
    
    model=LinearRegression()
    model.fit(X,y)
    Score=model.score(X,y)
    prediction=model.predict([[2014]])
    
    predicted=model.predict(X)

    mse=mean_squared_error(y,predicted)
    
    print(f"Model Score: {Score}    MSE: {mse}      2014 Prediction: {prediction}")
# Out:
# Model Score: 0.8567638807121551    MSE: 12485895.6475684      2014 Prediction: [[273367.79166667]]
# Model Score: 0.9220618816058199    MSE: 6537468.855901533      2014 Prediction: [[239888.50166667]]
# Model Score: 0.40791149394334003    MSE: 3438840.5422224053      2014 Prediction: [[260006.86833333]]
# Model Score: 0.9693647397629573    MSE: 45069537.05284655      2014 Prediction: [[368065.55500001]]

# %% [markdown]
# ### 3-9 has a very low R2 score because the dollar amounts do not change much from year to year, so the correlation is not very strong.  However, it has one of the best Mean Squared Error scores so it may in fact be useful for predicting.

# %% [markdown]
# ##  3-9  does not have much change.  only about 6,000 from high to low.  would scaling help?

# %%
## create df to analyze category 5

edata5=data.loc[(data['Store_type']=='e-Shop') & (data['prod_cat_code']==5)]
edata5.head()
# Out:
#     transaction_id  cust_id       DOB Gender  city_code  tran_date  \
# 12      1571002198   275023  09/03/71      M          6  2/20/2014
# 14     36554696014   269345  06/26/70      F         10  2/20/2014
# 15     56814940239   268799  06/27/79      M          9  2/20/2014
# 16     54295803788   270787  10/09/73      F          6  2/20/2014
# 43     80381707658   269407  04/25/78      F          1  2/19/2014
#
#    prod_subcat  prod_subcat_code prod_cat  prod_cat_code  Qty  Rate      Tax  \
# 12         DIY                 6    Books              5    4   587  246.540
# 14        Kids                 3    Books              5    3  1253  394.695
# 15     Fiction                 7    Books              5    5   368  193.200
# 16    Academic                12    Books              5    5   584  306.600
# 43         DIY                 6    Books              5    5   573  300.825
#
#     total_amt Store_type  transaction_month  transaction_year transaction_MoYr
# 12   2594.540     e-Shop                  2              2014           2/2014
# 14   4153.695     e-Shop                  2              2014           2/2014
# 15   2033.200     e-Shop                  2              2014           2/2014
# 16   3226.600     e-Shop                  2              2014           2/2014
# 43   3165.825     e-Shop                  2              2014           2/2014

# %%
##Category 5-11


edata5x=edata5.loc[edata5['prod_subcat_code']==11]
edata5x=edata5x.groupby('transaction_year').sum()
edata5x=edata5x.reset_index()
edata5x=edata5x.drop(3)
edata5x
    
X=edata5x["transaction_year"].values.reshape(-1,1)
y=edata5x["total_amt"].values.reshape(-1,1)
    
plt.scatter(X,y)
plt.title(f"E-Shop Category 5, Subcategory 11")
    
    
xx=edata5x["transaction_year"]
yy= edata5x["total_amt"]
    
m,b=np.polyfit(xx,yy,1)
plt.plot(xx, m*xx + b)
    
plt.show()
    
model=LinearRegression()
model.fit(X,y)
Score=model.score(X,y)
prediction=model.predict([[2014]])

predicted=model.predict(X)

mse=mean_squared_error(y,predicted)
    
print(f"Model Score: {Score}    MSE: {mse}      2014 Prediction: {prediction}")
# Out:
# Model Score: 0.9670647092012153    MSE: 68317042.36009172      2014 Prediction: [[186579.98666668]]
